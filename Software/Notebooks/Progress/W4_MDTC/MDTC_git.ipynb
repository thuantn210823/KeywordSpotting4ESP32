# %%
import torch
from torch import nn

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from torchinfo import summary

from mdtc_1 import MDTC
from mdtc_git import MDTC_git

# %%
model = MDTC_git(4, 4, 40, 64, 5, True, 64, 12)
x = torch.rand(128, 40, 81)
model(x).shape
# Out:
# Receptive Fields: 244
# torch.Size([128, 12])

# %%
summary(model, input_size = (128, 1, 40, 81))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# MDTC_git                                                [128, 12]                 --
# ├─MDTC: 1-1                                             [128, 81, 64]             --
# │    └─TCNBlock: 2-1                                    [128, 64, 81]             --
# │    │    └─DSDilatedConv1d: 3-1                        [128, 64, 81]             2,944
# │    │    └─BatchNorm1d: 3-2                            [128, 64, 81]             128
# │    │    └─ReLU: 3-3                                   [128, 64, 81]             --
# │    │    └─Conv1d: 3-4                                 [128, 64, 81]             4,160
# │    │    └─BatchNorm1d: 3-5                            [128, 64, 81]             128
# │    │    └─ReLU: 3-6                                   [128, 64, 81]             --
# │    └─ReLU: 2-2                                        [128, 64, 81]             --
# │    └─ModuleList: 2-3                                  --                        --
# │    │    └─TCNStack: 3-7                               [128, 64, 81]             36,352
# │    │    └─TCNStack: 3-8                               [128, 64, 81]             36,352
# │    │    └─TCNStack: 3-9                               [128, 64, 81]             36,352
# │    │    └─TCNStack: 3-10                              [128, 64, 81]             36,352
# ├─AdaptiveAvgPool1d: 1-2                                [128, 64, 1]              --
# ├─Linear: 1-3                                           [128, 64]                 4,160
# ├─ReLU: 1-4                                             [128, 64]                 --
# ├─Linear: 1-5                                           [128, 12]                 780
# =========================================================================================================
# Total params: 157,708
# Trainable params: 157,708
# Non-trainable params: 0
# Total mult-adds (G): 1.52
# =========================================================================================================
# Input size (MB): 1.66
# Forward/backward pass size (MB): 537.55
# Params size (MB): 0.63
# Estimated Total Size (MB): 539.84
# =========================================================================================================
