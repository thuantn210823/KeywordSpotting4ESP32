# %%
# !echo "const unsigned char model[] = {" > /content/model.h
# !cat hello_world_int8.tflite | xxd -i      >> /content/model.h
# !echo "};"                              >> /content/model.h

import os
model_h_size = os.path.getsize("model.h")
print(f"Header file, model.h, is {model_h_size:,} bytes.")
print("\nOpen the side panel (refresh if needed). Double click model.h to download the file.")
# Out:
# Header file, model.h, is 16,710 bytes.
#
# Open the side panel (refresh if needed). Double click model.h to download the file.

# %%
# !echo "const unsigned char model[] = {" > /content/gsc_bkup_model.h
# !cat /content/gsc_tflite_backup_model_quant.tflite | xxd -i      >> /content/gsc_bkup_model.h
# !echo "};"                              >> /content/gsc_bkup_model.h

import os
gsc_bkup_model_h_size = os.path.getsize("gsc_bkup_model.h")
print(f"Header file, model.h, is {gsc_bkup_model_h_size:,} bytes.")
print("\nOpen the side panel (refresh if needed). Double click model.h to download the file.")
# Out:
# Header file, model.h, is 700,864 bytes.
#
# Open the side panel (refresh if needed). Double click model.h to download the file.
